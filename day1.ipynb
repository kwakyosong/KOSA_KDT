# %% [markdown]
# <a href="https://colab.research.google.com/github/kwakyosong/KOSA_KDT/blob/main/day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('hello world!!')
# Out:
# hello world!!

# %%
import numpy as np
def f(x) :
  return 2*x**2 + 2

x = np.arange(-2,2.1,0.25)
print(x)
# Out:
# [-2.   -1.75 -1.5  -1.25 -1.   -0.75 -0.5  -0.25  0.    0.25  0.5   0.75
#   1.    1.25  1.5   1.75  2.  ]

# %%
y = f(x)
print(y)
# Out:
# [10.     8.125  6.5    5.125  4.     3.125  2.5    2.125  2.     2.125
#   2.5    3.125  4.     5.125  6.5    8.125 10.   ]

# %%
import matplotlib.pyplot as plt

plt.plot(y)
